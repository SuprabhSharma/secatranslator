# %% [markdown]
# <a href="https://colab.research.google.com/github/SuprabhSharma/secatranslator/blob/main/audio_to_text.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("welcome in google colab")
